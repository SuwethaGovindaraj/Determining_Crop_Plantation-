# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Importing & Checking the dataset

crop_df = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/crop_recommendation/train_set_label.csv")

crop_df.head()
crop_df.tail()
crop_df.info()
crop_df.describe()
crop_df.shape
crop_df.dtypes
crop_df.isnull().sum()
crop_df["crop"].sort_values().unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650 entries, 0 to 1649
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            1650 non-null   float64
#  1   P            1650 non-null   float64
#  2   K            1650 non-null   float64
#  3   temperature  1650 non-null   float64
#  4   humidity     1650 non-null   float64
#  5   ph           1650 non-null   float64
#  6   rainfall     1650 non-null   float64
#  7   crop         1650 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 103.2+ KB
# array(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize',
#        'mango', 'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya',
#        'pigeonpeas', 'pomegranate', 'rice', 'watermelon'], dtype=object)

# %%
crop_df["crop"].unique()
# Out:
# array(['apple', 'chickpea', 'jute', 'coffee', 'watermelon', 'coconut',
#        'grapes', 'mango', 'mothbeans', 'pomegranate', 'mungbean',
#        'banana', 'blackgram', 'orange', 'rice', 'lentil', 'maize',
#        'pigeonpeas', 'kidneybeans', 'papaya', 'muskmelon', 'cotton'],
#       dtype=object)

# %%
##Data Visualization

# Plot 1
plt.figure(figsize=(15,10))
plt.hist(crop_df["N"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the Nitrogen")
plt.xlabel("Ratio of Nitrogen content in soil")
plt.ylabel("Count")

# Plot 2
plt.figure(figsize=(15,10))
plt.hist(crop_df["P"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the Phosphorus")
plt.xlabel("Ratio of Phosphorus content in soil")
plt.ylabel("Count")

# Plot 3
plt.figure(figsize=(15,10))
plt.hist(crop_df["K"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the Potassium")
plt.xlabel("Ratio of Potassium content in soil")
plt.ylabel("Count")

# Plot 4
plt.figure(figsize=(15,10))
plt.hist(crop_df["temperature"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the Temperature")
plt.xlabel("Temperature in degree Celsius")
plt.ylabel("Count")

# Plot 5
plt.figure(figsize=(15,10))
plt.hist(crop_df["humidity"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the Relative Humidity")
plt.xlabel("Temperature in relative humidity in %")
plt.ylabel("Count")

# Plot 6 
plt.figure(figsize=(15,10))
plt.hist(crop_df["ph"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the ph Value")
plt.xlabel("ph value of the soil")
plt.ylabel("Count")

# Plot 7 
plt.figure(figsize=(15,10))
plt.hist(crop_df["rainfall"], bins=75, color='pink', edgecolor='black', linewidth=1.2)
plt.title("Distribution of the Rainfall")
plt.xlabel("Rainfall in mm")
plt.ylabel("Count")

# Plot 8.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="N", data=crop_df)
plt.title("Barplot to show how Nitrogen effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("NITROGEN")

# Plot 8.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="N", data=crop_df)
plt.title("Boxplot to show how Nitrogen effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("NITROGEN")

# Plot 9.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="P", data=crop_df)
plt.title("Barplot to show how Phosphorus effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("PHOSPHORUS") 

# Plot 9.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="P", data=crop_df)
plt.title("Boxplot to show how Phosphorus effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("PHOSPHORUS")

# Plot 10.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="K", data=crop_df)
plt.title("Barplot to show how Potassium effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("POTASSIUM") 

# Plot 10.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="P", data=crop_df)
plt.title("Boxplot to show how Potassium effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("POTASSIUM")

# Plot 11.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="temperature", data=crop_df)
plt.title("Barplot to show how temperature effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("TEMPERATURE") 

# Plot 11.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="P", data=crop_df)
plt.title("Boxplot to show how temperature effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("TEMPERATURE")

# Plot 11.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="temperature", data=crop_df)
plt.title("Barplot to show how temperature effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("TEMPERATURE") 

# Plot 11.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="P", data=crop_df)
plt.title("Boxplot to show how temperature effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("TEMPERATURE")

# Plot 12.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="humidity", data=crop_df)
plt.title("Barplot to show how humidity effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("HUMIDITY") 

# Plot 12.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="humidity", data=crop_df)
plt.title("Boxplot to show how humidity effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("HUMIDITY")

# Plot 13.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="ph", data=crop_df)
plt.title("Barplot to show how ph effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("ph VALUE") 

# Plot 13.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="ph", data=crop_df)
plt.title("Boxplot to show how ph effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("ph VALUE")

# Plot 14.1 
plt.figure(figsize=(20,10))
sns.barplot(x="crop", y="rainfall", data=crop_df)
plt.title("Barplot to show how rainfall effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("RAINFALL") 

# Plot 14.2
plt.figure(figsize=(20,10))
sns.boxplot(x="crop", y="rainfall", data=crop_df)
plt.title("Boxplot to show how rainfall effects different kinds of crop")
plt.xlabel("CROPS")
plt.ylabel("RAINFALL")
# Out:
# C:\Users\Suwetha\AppData\Local\Temp/ipykernel_7072/2498378107.py:144: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20,10))
# Text(0, 0.5, 'RAINFALL')

# %%
cor=crop_df.corr()
print (cor)
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.232892 -0.143022     0.014088  0.185919  0.080087
# P           -0.232892  1.000000  0.735456    -0.133283 -0.119861 -0.145958
# K           -0.143022  0.735456  1.000000    -0.162041  0.188512 -0.193294
# temperature  0.014088 -0.133283 -0.162041     1.000000  0.201797 -0.018037
# humidity     0.185919 -0.119861  0.188512     0.201797  1.000000 -0.011764
# ph           0.080087 -0.145958 -0.193294    -0.018037 -0.011764  1.000000
# rainfall     0.049705 -0.064344 -0.054222     0.000306  0.105829 -0.138397
#
#              rainfall
# N            0.049705
# P           -0.064344
# K           -0.054222
# temperature  0.000306
# humidity     0.105829
# ph          -0.138397
# rainfall     1.000000

# %%
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
##Partitioning the dataset

from sklearn.model_selection import train_test_split

X = crop_df.drop("crop", axis=1)
y = crop_df["crop"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
##Building the machine learning model

from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
model_1= RandomForestClassifier()

# %%
model_1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model_1.predict(X_test)
# Out:
# array(['apple', 'mango', 'coffee', 'muskmelon', 'papaya', 'banana',
#        'jute', 'grapes', 'chickpea', 'grapes', 'apple', 'mungbean',
#        'muskmelon', 'coffee', 'pigeonpeas', 'blackgram', 'apple',
#        'grapes', 'orange', 'pigeonpeas', 'chickpea', 'coffee', 'mango',
#        'maize', 'mothbeans', 'blackgram', 'mango', 'coconut', 'grapes',
#        'jute', 'mothbeans', 'pigeonpeas', 'pomegranate', 'maize',
#        'blackgram', 'jute', 'mango', 'banana', 'kidneybeans', 'muskmelon',
#        'muskmelon', 'maize', 'lentil', 'mango', 'apple', 'maize',
#        'pomegranate', 'orange', 'mothbeans', 'chickpea', 'banana',
#        'watermelon', 'coconut', 'coffee', 'mango', 'muskmelon', 'lentil',
#        'watermelon', 'papaya', 'mothbeans', 'banana', 'watermelon',
#        'mothbeans', 'mungbean', 'mango', 'maize', 'lentil', 'orange',
#        'orange', 'orange', 'kidneybeans', 'orange', 'apple', 'grapes',
#        'kidneybeans', 'mango', 'apple', 'pomegranate', 'blackgram',
#        'mungbean', 'jute', 'grapes', 'cotton', 'papaya', 'lentil',
#        'kidneybeans', 'pomegranate', 'maize', 'grapes', 'banana',
#        'watermelon', 'blackgram', 'jute', 'muskmelon', 'kidneybeans',
#        'coffee', 'lentil', 'maize', 'coconut', 'apple', 'coconut',
#        'kidneybeans', 'mungbean', 'mungbean', 'mothbeans', 'jute',
#        'pomegranate', 'mango', 'chickpea', 'pigeonpeas', 'banana',
#        'coffee', 'mungbean', 'banana', 'watermelon', 'pigeonpeas',
#        'papaya', 'papaya', 'mungbean', 'lentil', 'mango', 'mungbean',
#        'rice', 'chickpea', 'apple', 'mungbean', 'mothbeans', 'rice',
#        'banana', 'papaya', 'coconut', 'blackgram', 'apple', 'chickpea',
#        'muskmelon', 'banana', 'chickpea', 'pigeonpeas', 'banana',
#        'muskmelon', 'chickpea', 'coffee', 'jute', 'rice', 'coffee',
#        'orange', 'grapes', 'rice', 'pigeonpeas', 'kidneybeans', 'maize',
#        'papaya', 'orange', 'maize', 'mango', 'jute', 'maize', 'jute',
#        'cotton', 'mango', 'mango', 'lentil', 'kidneybeans', 'kidneybeans',
#        'mothbeans', 'lentil', 'cotton', 'maize', 'rice', 'grapes',
#        'orange', 'cotton', 'muskmelon', 'mothbeans', 'mungbean',
#        'mothbeans', 'jute', 'pigeonpeas', 'coffee', 'banana',
#        'kidneybeans', 'banana', 'watermelon', 'grapes', 'pigeonpeas',
#        'coffee', 'lentil', 'banana', 'maize', 'chickpea', 'watermelon',
#        'chickpea', 'cotton', 'coffee', 'jute', 'pomegranate', 'maize',
#        'coffee', 'maize', 'mothbeans', 'mango', 'orange', 'pigeonpeas',
#        'mungbean', 'banana', 'lentil', 'mothbeans', 'papaya', 'mango',
#        'blackgram', 'orange', 'mothbeans', 'muskmelon', 'lentil',
#        'orange', 'mothbeans', 'grapes', 'mango', 'chickpea', 'lentil',
#        'blackgram', 'papaya', 'pomegranate', 'maize', 'pomegranate',
#        'orange', 'muskmelon', 'mango', 'maize', 'rice', 'mothbeans',
#        'coconut', 'orange', 'coconut', 'mothbeans', 'grapes', 'banana',
#        'jute', 'coconut', 'apple', 'pigeonpeas', 'grapes', 'grapes',
#        'coconut', 'coffee', 'rice', 'muskmelon', 'watermelon',
#        'watermelon', 'banana', 'apple', 'chickpea', 'papaya', 'coffee',
#        'grapes', 'orange', 'blackgram', 'papaya', 'coconut', 'coconut',
#        'grapes', 'kidneybeans', 'kidneybeans', 'cotton', 'coffee',
#        'pigeonpeas', 'pigeonpeas', 'mango', 'lentil', 'lentil',
#        'watermelon', 'maize', 'kidneybeans', 'mothbeans', 'rice',
#        'lentil', 'rice', 'mungbean', 'blackgram', 'watermelon', 'coffee',
#        'chickpea', 'papaya', 'watermelon', 'lentil', 'mothbeans',
#        'papaya', 'jute', 'pomegranate', 'grapes', 'maize', 'coconut',
#        'maize', 'grapes', 'coffee', 'mothbeans', 'papaya', 'chickpea',
#        'pomegranate', 'pomegranate', 'muskmelon', 'pomegranate', 'jute',
#        'banana', 'chickpea', 'jute', 'maize', 'coconut', 'grapes',
#        'apple', 'orange', 'chickpea', 'orange', 'watermelon',
#        'kidneybeans', 'grapes', 'banana', 'lentil', 'grapes', 'jute',
#        'apple', 'kidneybeans', 'coconut', 'mango', 'papaya',
#        'pomegranate', 'rice', 'pomegranate', 'chickpea', 'pigeonpeas',
#        'muskmelon', 'cotton', 'grapes', 'jute', 'coffee', 'banana',
#        'mothbeans', 'coffee', 'banana', 'blackgram', 'jute', 'cotton',
#        'lentil', 'grapes', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'banana', 'mothbeans', 'coconut', 'apple', 'coconut', 'cotton',
#        'mothbeans', 'pomegranate', 'rice', 'coconut', 'pomegranate',
#        'pomegranate', 'chickpea', 'kidneybeans', 'banana', 'mungbean',
#        'coconut', 'maize', 'orange', 'orange', 'cotton', 'mango',
#        'cotton', 'orange', 'grapes', 'orange', 'rice', 'mungbean',
#        'papaya', 'papaya', 'grapes', 'kidneybeans', 'coconut', 'mungbean',
#        'grapes', 'maize', 'papaya', 'banana', 'jute', 'mothbeans',
#        'mungbean', 'cotton', 'muskmelon', 'rice', 'mango', 'coffee',
#        'banana', 'pigeonpeas', 'pomegranate', 'coconut', 'papaya',
#        'apple', 'mango', 'mango', 'jute', 'chickpea', 'apple',
#        'blackgram', 'cotton', 'muskmelon', 'orange', 'grapes',
#        'kidneybeans', 'pigeonpeas', 'watermelon', 'mungbean', 'maize',
#        'pigeonpeas', 'lentil', 'mothbeans', 'mothbeans', 'grapes', 'rice',
#        'watermelon', 'mango', 'lentil', 'rice', 'papaya', 'rice',
#        'pomegranate', 'blackgram', 'coffee', 'grapes', 'mothbeans',
#        'pomegranate', 'maize', 'chickpea', 'coffee', 'coconut', 'banana',
#        'lentil', 'grapes', 'papaya', 'lentil', 'chickpea', 'papaya',
#        'chickpea', 'lentil', 'banana', 'mungbean', 'watermelon', 'lentil',
#        'coffee', 'papaya', 'mothbeans', 'blackgram', 'watermelon',
#        'lentil', 'blackgram', 'mungbean', 'maize', 'mothbeans', 'papaya',
#        'blackgram', 'coffee', 'rice', 'grapes', 'pomegranate',
#        'mothbeans', 'banana', 'apple', 'pomegranate', 'kidneybeans',
#        'jute', 'apple', 'mungbean', 'chickpea', 'apple', 'mothbeans',
#        'coconut', 'mungbean', 'muskmelon', 'apple', 'grapes', 'mungbean',
#        'muskmelon', 'coconut', 'chickpea', 'coffee', 'lentil', 'mango',
#        'pomegranate', 'jute', 'orange', 'maize', 'kidneybeans',
#        'mungbean'], dtype=object)

# %%
y_pred_1=model_1.predict(X_test)
y_pred_1
# Out:
# array(['apple', 'mango', 'coffee', 'muskmelon', 'papaya', 'banana',
#        'jute', 'grapes', 'chickpea', 'grapes', 'apple', 'mungbean',
#        'muskmelon', 'coffee', 'pigeonpeas', 'blackgram', 'apple',
#        'grapes', 'orange', 'pigeonpeas', 'chickpea', 'coffee', 'mango',
#        'maize', 'mothbeans', 'blackgram', 'mango', 'coconut', 'grapes',
#        'jute', 'mothbeans', 'pigeonpeas', 'pomegranate', 'maize',
#        'blackgram', 'jute', 'mango', 'banana', 'kidneybeans', 'muskmelon',
#        'muskmelon', 'maize', 'lentil', 'mango', 'apple', 'maize',
#        'pomegranate', 'orange', 'mothbeans', 'chickpea', 'banana',
#        'watermelon', 'coconut', 'coffee', 'mango', 'muskmelon', 'lentil',
#        'watermelon', 'papaya', 'mothbeans', 'banana', 'watermelon',
#        'mothbeans', 'mungbean', 'mango', 'maize', 'lentil', 'orange',
#        'orange', 'orange', 'kidneybeans', 'orange', 'apple', 'grapes',
#        'kidneybeans', 'mango', 'apple', 'pomegranate', 'blackgram',
#        'mungbean', 'jute', 'grapes', 'cotton', 'papaya', 'lentil',
#        'kidneybeans', 'pomegranate', 'maize', 'grapes', 'banana',
#        'watermelon', 'blackgram', 'jute', 'muskmelon', 'kidneybeans',
#        'coffee', 'lentil', 'maize', 'coconut', 'apple', 'coconut',
#        'kidneybeans', 'mungbean', 'mungbean', 'mothbeans', 'jute',
#        'pomegranate', 'mango', 'chickpea', 'pigeonpeas', 'banana',
#        'coffee', 'mungbean', 'banana', 'watermelon', 'pigeonpeas',
#        'papaya', 'papaya', 'mungbean', 'lentil', 'mango', 'mungbean',
#        'rice', 'chickpea', 'apple', 'mungbean', 'mothbeans', 'rice',
#        'banana', 'papaya', 'coconut', 'blackgram', 'apple', 'chickpea',
#        'muskmelon', 'banana', 'chickpea', 'pigeonpeas', 'banana',
#        'muskmelon', 'chickpea', 'coffee', 'jute', 'rice', 'coffee',
#        'orange', 'grapes', 'rice', 'pigeonpeas', 'kidneybeans', 'maize',
#        'papaya', 'orange', 'maize', 'mango', 'jute', 'maize', 'jute',
#        'cotton', 'mango', 'mango', 'lentil', 'kidneybeans', 'kidneybeans',
#        'mothbeans', 'lentil', 'cotton', 'maize', 'rice', 'grapes',
#        'orange', 'cotton', 'muskmelon', 'mothbeans', 'mungbean',
#        'mothbeans', 'jute', 'pigeonpeas', 'coffee', 'banana',
#        'kidneybeans', 'banana', 'watermelon', 'grapes', 'pigeonpeas',
#        'coffee', 'lentil', 'banana', 'maize', 'chickpea', 'watermelon',
#        'chickpea', 'cotton', 'coffee', 'jute', 'pomegranate', 'maize',
#        'coffee', 'maize', 'mothbeans', 'mango', 'orange', 'pigeonpeas',
#        'mungbean', 'banana', 'lentil', 'mothbeans', 'papaya', 'mango',
#        'blackgram', 'orange', 'mothbeans', 'muskmelon', 'lentil',
#        'orange', 'mothbeans', 'grapes', 'mango', 'chickpea', 'lentil',
#        'blackgram', 'papaya', 'pomegranate', 'maize', 'pomegranate',
#        'orange', 'muskmelon', 'mango', 'maize', 'rice', 'mothbeans',
#        'coconut', 'orange', 'coconut', 'mothbeans', 'grapes', 'banana',
#        'jute', 'coconut', 'apple', 'pigeonpeas', 'grapes', 'grapes',
#        'coconut', 'coffee', 'rice', 'muskmelon', 'watermelon',
#        'watermelon', 'banana', 'apple', 'chickpea', 'papaya', 'coffee',
#        'grapes', 'orange', 'blackgram', 'papaya', 'coconut', 'coconut',
#        'grapes', 'kidneybeans', 'kidneybeans', 'cotton', 'coffee',
#        'pigeonpeas', 'pigeonpeas', 'mango', 'lentil', 'lentil',
#        'watermelon', 'maize', 'kidneybeans', 'mothbeans', 'rice',
#        'lentil', 'rice', 'mungbean', 'blackgram', 'watermelon', 'coffee',
#        'chickpea', 'papaya', 'watermelon', 'lentil', 'mothbeans',
#        'papaya', 'jute', 'pomegranate', 'grapes', 'maize', 'coconut',
#        'maize', 'grapes', 'coffee', 'mothbeans', 'papaya', 'chickpea',
#        'pomegranate', 'pomegranate', 'muskmelon', 'pomegranate', 'jute',
#        'banana', 'chickpea', 'jute', 'maize', 'coconut', 'grapes',
#        'apple', 'orange', 'chickpea', 'orange', 'watermelon',
#        'kidneybeans', 'grapes', 'banana', 'lentil', 'grapes', 'jute',
#        'apple', 'kidneybeans', 'coconut', 'mango', 'papaya',
#        'pomegranate', 'rice', 'pomegranate', 'chickpea', 'pigeonpeas',
#        'muskmelon', 'cotton', 'grapes', 'jute', 'coffee', 'banana',
#        'mothbeans', 'coffee', 'banana', 'blackgram', 'jute', 'cotton',
#        'lentil', 'grapes', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'banana', 'mothbeans', 'coconut', 'apple', 'coconut', 'cotton',
#        'mothbeans', 'pomegranate', 'rice', 'coconut', 'pomegranate',
#        'pomegranate', 'chickpea', 'kidneybeans', 'banana', 'mungbean',
#        'coconut', 'maize', 'orange', 'orange', 'cotton', 'mango',
#        'cotton', 'orange', 'grapes', 'orange', 'rice', 'mungbean',
#        'papaya', 'papaya', 'grapes', 'kidneybeans', 'coconut', 'mungbean',
#        'grapes', 'maize', 'papaya', 'banana', 'jute', 'mothbeans',
#        'mungbean', 'cotton', 'muskmelon', 'rice', 'mango', 'coffee',
#        'banana', 'pigeonpeas', 'pomegranate', 'coconut', 'papaya',
#        'apple', 'mango', 'mango', 'jute', 'chickpea', 'apple',
#        'blackgram', 'cotton', 'muskmelon', 'orange', 'grapes',
#        'kidneybeans', 'pigeonpeas', 'watermelon', 'mungbean', 'maize',
#        'pigeonpeas', 'lentil', 'mothbeans', 'mothbeans', 'grapes', 'rice',
#        'watermelon', 'mango', 'lentil', 'rice', 'papaya', 'rice',
#        'pomegranate', 'blackgram', 'coffee', 'grapes', 'mothbeans',
#        'pomegranate', 'maize', 'chickpea', 'coffee', 'coconut', 'banana',
#        'lentil', 'grapes', 'papaya', 'lentil', 'chickpea', 'papaya',
#        'chickpea', 'lentil', 'banana', 'mungbean', 'watermelon', 'lentil',
#        'coffee', 'papaya', 'mothbeans', 'blackgram', 'watermelon',
#        'lentil', 'blackgram', 'mungbean', 'maize', 'mothbeans', 'papaya',
#        'blackgram', 'coffee', 'rice', 'grapes', 'pomegranate',
#        'mothbeans', 'banana', 'apple', 'pomegranate', 'kidneybeans',
#        'jute', 'apple', 'mungbean', 'chickpea', 'apple', 'mothbeans',
#        'coconut', 'mungbean', 'muskmelon', 'apple', 'grapes', 'mungbean',
#        'muskmelon', 'coconut', 'chickpea', 'coffee', 'lentil', 'mango',
#        'pomegranate', 'jute', 'orange', 'maize', 'kidneybeans',
#        'mungbean'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred_1)
# Out:
# 0.98989898989899

# %%
from xgboost import XGBClassifier
model_2= XGBClassifier()

# %%
model_2.fit(X_train, y_train)
# Out:
# [21:29:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
model_2.predict(X_test)
# Out:
# array(['apple', 'mango', 'coffee', 'muskmelon', 'papaya', 'banana',
#        'rice', 'grapes', 'chickpea', 'grapes', 'apple', 'mungbean',
#        'muskmelon', 'coffee', 'pigeonpeas', 'blackgram', 'apple',
#        'grapes', 'orange', 'pigeonpeas', 'chickpea', 'coffee', 'mango',
#        'maize', 'lentil', 'blackgram', 'mango', 'coconut', 'grapes',
#        'jute', 'mothbeans', 'pigeonpeas', 'pomegranate', 'maize',
#        'blackgram', 'jute', 'mango', 'banana', 'kidneybeans', 'muskmelon',
#        'muskmelon', 'maize', 'lentil', 'mango', 'apple', 'maize',
#        'pomegranate', 'orange', 'mothbeans', 'chickpea', 'banana',
#        'watermelon', 'coconut', 'coffee', 'mango', 'muskmelon', 'lentil',
#        'watermelon', 'papaya', 'mothbeans', 'banana', 'watermelon',
#        'mothbeans', 'mungbean', 'mango', 'maize', 'lentil', 'orange',
#        'orange', 'orange', 'kidneybeans', 'orange', 'apple', 'grapes',
#        'kidneybeans', 'mango', 'grapes', 'pomegranate', 'blackgram',
#        'mungbean', 'jute', 'grapes', 'cotton', 'papaya', 'lentil',
#        'kidneybeans', 'pomegranate', 'maize', 'grapes', 'banana',
#        'watermelon', 'blackgram', 'jute', 'muskmelon', 'kidneybeans',
#        'coffee', 'lentil', 'maize', 'coconut', 'apple', 'coconut',
#        'kidneybeans', 'mungbean', 'mungbean', 'mothbeans', 'jute',
#        'pomegranate', 'mango', 'chickpea', 'pigeonpeas', 'banana',
#        'coffee', 'mungbean', 'banana', 'watermelon', 'pigeonpeas',
#        'papaya', 'papaya', 'mungbean', 'lentil', 'mango', 'mungbean',
#        'rice', 'chickpea', 'apple', 'mungbean', 'mothbeans', 'rice',
#        'banana', 'papaya', 'coconut', 'blackgram', 'apple', 'chickpea',
#        'muskmelon', 'banana', 'chickpea', 'pigeonpeas', 'banana',
#        'muskmelon', 'chickpea', 'coffee', 'jute', 'rice', 'coffee',
#        'orange', 'grapes', 'rice', 'pigeonpeas', 'kidneybeans', 'maize',
#        'papaya', 'orange', 'maize', 'mango', 'jute', 'maize', 'jute',
#        'cotton', 'mango', 'mango', 'lentil', 'kidneybeans', 'kidneybeans',
#        'mothbeans', 'lentil', 'cotton', 'maize', 'rice', 'grapes',
#        'orange', 'cotton', 'muskmelon', 'mothbeans', 'mothbeans',
#        'mothbeans', 'jute', 'pigeonpeas', 'coffee', 'banana',
#        'kidneybeans', 'banana', 'watermelon', 'grapes', 'pigeonpeas',
#        'coffee', 'lentil', 'banana', 'maize', 'chickpea', 'watermelon',
#        'chickpea', 'cotton', 'coffee', 'rice', 'pomegranate', 'maize',
#        'coffee', 'maize', 'mothbeans', 'mango', 'orange', 'pigeonpeas',
#        'mungbean', 'banana', 'lentil', 'mothbeans', 'papaya', 'mango',
#        'blackgram', 'orange', 'mothbeans', 'muskmelon', 'lentil',
#        'orange', 'mothbeans', 'grapes', 'mango', 'chickpea', 'lentil',
#        'blackgram', 'papaya', 'pomegranate', 'maize', 'pomegranate',
#        'orange', 'muskmelon', 'mango', 'maize', 'rice', 'mothbeans',
#        'coconut', 'orange', 'coconut', 'mothbeans', 'grapes', 'banana',
#        'jute', 'coconut', 'apple', 'pigeonpeas', 'grapes', 'grapes',
#        'coconut', 'coffee', 'rice', 'muskmelon', 'watermelon',
#        'watermelon', 'banana', 'apple', 'chickpea', 'papaya', 'coffee',
#        'grapes', 'orange', 'blackgram', 'papaya', 'coconut', 'coconut',
#        'grapes', 'kidneybeans', 'kidneybeans', 'cotton', 'coffee',
#        'pigeonpeas', 'pigeonpeas', 'mango', 'lentil', 'lentil',
#        'watermelon', 'maize', 'kidneybeans', 'mothbeans', 'rice',
#        'lentil', 'rice', 'mungbean', 'blackgram', 'watermelon', 'coffee',
#        'chickpea', 'papaya', 'watermelon', 'lentil', 'mothbeans',
#        'papaya', 'jute', 'pomegranate', 'grapes', 'maize', 'coconut',
#        'maize', 'grapes', 'coffee', 'mothbeans', 'papaya', 'chickpea',
#        'pomegranate', 'pomegranate', 'muskmelon', 'pomegranate', 'jute',
#        'banana', 'chickpea', 'jute', 'maize', 'coconut', 'grapes',
#        'apple', 'orange', 'chickpea', 'orange', 'watermelon',
#        'kidneybeans', 'grapes', 'banana', 'lentil', 'grapes', 'jute',
#        'apple', 'kidneybeans', 'coconut', 'mango', 'papaya',
#        'pomegranate', 'rice', 'pomegranate', 'chickpea', 'pigeonpeas',
#        'muskmelon', 'cotton', 'grapes', 'jute', 'coffee', 'banana',
#        'mothbeans', 'coffee', 'banana', 'blackgram', 'jute', 'cotton',
#        'lentil', 'grapes', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'banana', 'mothbeans', 'coconut', 'apple', 'coconut', 'cotton',
#        'mothbeans', 'pomegranate', 'rice', 'coconut', 'pomegranate',
#        'papaya', 'chickpea', 'kidneybeans', 'banana', 'mungbean',
#        'coconut', 'maize', 'orange', 'orange', 'cotton', 'mango',
#        'cotton', 'orange', 'grapes', 'orange', 'rice', 'mungbean',
#        'papaya', 'papaya', 'grapes', 'kidneybeans', 'coconut', 'mungbean',
#        'grapes', 'maize', 'papaya', 'banana', 'jute', 'mothbeans',
#        'mungbean', 'cotton', 'muskmelon', 'rice', 'mango', 'coffee',
#        'banana', 'pigeonpeas', 'pomegranate', 'coconut', 'papaya',
#        'apple', 'mango', 'mango', 'jute', 'chickpea', 'apple',
#        'blackgram', 'cotton', 'muskmelon', 'orange', 'grapes',
#        'kidneybeans', 'pigeonpeas', 'watermelon', 'mungbean', 'maize',
#        'pigeonpeas', 'lentil', 'mothbeans', 'mothbeans', 'grapes', 'rice',
#        'watermelon', 'mango', 'lentil', 'rice', 'papaya', 'rice',
#        'pomegranate', 'blackgram', 'coffee', 'grapes', 'mothbeans',
#        'pomegranate', 'maize', 'chickpea', 'coffee', 'coconut', 'banana',
#        'lentil', 'grapes', 'papaya', 'lentil', 'chickpea', 'papaya',
#        'chickpea', 'lentil', 'banana', 'mungbean', 'watermelon', 'lentil',
#        'coffee', 'papaya', 'mothbeans', 'blackgram', 'watermelon',
#        'lentil', 'blackgram', 'mungbean', 'maize', 'mothbeans', 'papaya',
#        'blackgram', 'coffee', 'rice', 'grapes', 'pomegranate',
#        'mothbeans', 'banana', 'apple', 'pomegranate', 'kidneybeans',
#        'jute', 'apple', 'mungbean', 'chickpea', 'apple', 'mothbeans',
#        'coconut', 'mungbean', 'muskmelon', 'grapes', 'grapes', 'mungbean',
#        'muskmelon', 'coconut', 'chickpea', 'coffee', 'lentil', 'mango',
#        'pomegranate', 'jute', 'orange', 'maize', 'kidneybeans',
#        'mungbean'], dtype=object)

# %%
y_pred_2=model_2.predict(X_test)
y_pred_2
# Out:
# array(['apple', 'mango', 'coffee', 'muskmelon', 'papaya', 'banana',
#        'rice', 'grapes', 'chickpea', 'grapes', 'apple', 'mungbean',
#        'muskmelon', 'coffee', 'pigeonpeas', 'blackgram', 'apple',
#        'grapes', 'orange', 'pigeonpeas', 'chickpea', 'coffee', 'mango',
#        'maize', 'lentil', 'blackgram', 'mango', 'coconut', 'grapes',
#        'jute', 'mothbeans', 'pigeonpeas', 'pomegranate', 'maize',
#        'blackgram', 'jute', 'mango', 'banana', 'kidneybeans', 'muskmelon',
#        'muskmelon', 'maize', 'lentil', 'mango', 'apple', 'maize',
#        'pomegranate', 'orange', 'mothbeans', 'chickpea', 'banana',
#        'watermelon', 'coconut', 'coffee', 'mango', 'muskmelon', 'lentil',
#        'watermelon', 'papaya', 'mothbeans', 'banana', 'watermelon',
#        'mothbeans', 'mungbean', 'mango', 'maize', 'lentil', 'orange',
#        'orange', 'orange', 'kidneybeans', 'orange', 'apple', 'grapes',
#        'kidneybeans', 'mango', 'grapes', 'pomegranate', 'blackgram',
#        'mungbean', 'jute', 'grapes', 'cotton', 'papaya', 'lentil',
#        'kidneybeans', 'pomegranate', 'maize', 'grapes', 'banana',
#        'watermelon', 'blackgram', 'jute', 'muskmelon', 'kidneybeans',
#        'coffee', 'lentil', 'maize', 'coconut', 'apple', 'coconut',
#        'kidneybeans', 'mungbean', 'mungbean', 'mothbeans', 'jute',
#        'pomegranate', 'mango', 'chickpea', 'pigeonpeas', 'banana',
#        'coffee', 'mungbean', 'banana', 'watermelon', 'pigeonpeas',
#        'papaya', 'papaya', 'mungbean', 'lentil', 'mango', 'mungbean',
#        'rice', 'chickpea', 'apple', 'mungbean', 'mothbeans', 'rice',
#        'banana', 'papaya', 'coconut', 'blackgram', 'apple', 'chickpea',
#        'muskmelon', 'banana', 'chickpea', 'pigeonpeas', 'banana',
#        'muskmelon', 'chickpea', 'coffee', 'jute', 'rice', 'coffee',
#        'orange', 'grapes', 'rice', 'pigeonpeas', 'kidneybeans', 'maize',
#        'papaya', 'orange', 'maize', 'mango', 'jute', 'maize', 'jute',
#        'cotton', 'mango', 'mango', 'lentil', 'kidneybeans', 'kidneybeans',
#        'mothbeans', 'lentil', 'cotton', 'maize', 'rice', 'grapes',
#        'orange', 'cotton', 'muskmelon', 'mothbeans', 'mothbeans',
#        'mothbeans', 'jute', 'pigeonpeas', 'coffee', 'banana',
#        'kidneybeans', 'banana', 'watermelon', 'grapes', 'pigeonpeas',
#        'coffee', 'lentil', 'banana', 'maize', 'chickpea', 'watermelon',
#        'chickpea', 'cotton', 'coffee', 'rice', 'pomegranate', 'maize',
#        'coffee', 'maize', 'mothbeans', 'mango', 'orange', 'pigeonpeas',
#        'mungbean', 'banana', 'lentil', 'mothbeans', 'papaya', 'mango',
#        'blackgram', 'orange', 'mothbeans', 'muskmelon', 'lentil',
#        'orange', 'mothbeans', 'grapes', 'mango', 'chickpea', 'lentil',
#        'blackgram', 'papaya', 'pomegranate', 'maize', 'pomegranate',
#        'orange', 'muskmelon', 'mango', 'maize', 'rice', 'mothbeans',
#        'coconut', 'orange', 'coconut', 'mothbeans', 'grapes', 'banana',
#        'jute', 'coconut', 'apple', 'pigeonpeas', 'grapes', 'grapes',
#        'coconut', 'coffee', 'rice', 'muskmelon', 'watermelon',
#        'watermelon', 'banana', 'apple', 'chickpea', 'papaya', 'coffee',
#        'grapes', 'orange', 'blackgram', 'papaya', 'coconut', 'coconut',
#        'grapes', 'kidneybeans', 'kidneybeans', 'cotton', 'coffee',
#        'pigeonpeas', 'pigeonpeas', 'mango', 'lentil', 'lentil',
#        'watermelon', 'maize', 'kidneybeans', 'mothbeans', 'rice',
#        'lentil', 'rice', 'mungbean', 'blackgram', 'watermelon', 'coffee',
#        'chickpea', 'papaya', 'watermelon', 'lentil', 'mothbeans',
#        'papaya', 'jute', 'pomegranate', 'grapes', 'maize', 'coconut',
#        'maize', 'grapes', 'coffee', 'mothbeans', 'papaya', 'chickpea',
#        'pomegranate', 'pomegranate', 'muskmelon', 'pomegranate', 'jute',
#        'banana', 'chickpea', 'jute', 'maize', 'coconut', 'grapes',
#        'apple', 'orange', 'chickpea', 'orange', 'watermelon',
#        'kidneybeans', 'grapes', 'banana', 'lentil', 'grapes', 'jute',
#        'apple', 'kidneybeans', 'coconut', 'mango', 'papaya',
#        'pomegranate', 'rice', 'pomegranate', 'chickpea', 'pigeonpeas',
#        'muskmelon', 'cotton', 'grapes', 'jute', 'coffee', 'banana',
#        'mothbeans', 'coffee', 'banana', 'blackgram', 'jute', 'cotton',
#        'lentil', 'grapes', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'banana', 'mothbeans', 'coconut', 'apple', 'coconut', 'cotton',
#        'mothbeans', 'pomegranate', 'rice', 'coconut', 'pomegranate',
#        'papaya', 'chickpea', 'kidneybeans', 'banana', 'mungbean',
#        'coconut', 'maize', 'orange', 'orange', 'cotton', 'mango',
#        'cotton', 'orange', 'grapes', 'orange', 'rice', 'mungbean',
#        'papaya', 'papaya', 'grapes', 'kidneybeans', 'coconut', 'mungbean',
#        'grapes', 'maize', 'papaya', 'banana', 'jute', 'mothbeans',
#        'mungbean', 'cotton', 'muskmelon', 'rice', 'mango', 'coffee',
#        'banana', 'pigeonpeas', 'pomegranate', 'coconut', 'papaya',
#        'apple', 'mango', 'mango', 'jute', 'chickpea', 'apple',
#        'blackgram', 'cotton', 'muskmelon', 'orange', 'grapes',
#        'kidneybeans', 'pigeonpeas', 'watermelon', 'mungbean', 'maize',
#        'pigeonpeas', 'lentil', 'mothbeans', 'mothbeans', 'grapes', 'rice',
#        'watermelon', 'mango', 'lentil', 'rice', 'papaya', 'rice',
#        'pomegranate', 'blackgram', 'coffee', 'grapes', 'mothbeans',
#        'pomegranate', 'maize', 'chickpea', 'coffee', 'coconut', 'banana',
#        'lentil', 'grapes', 'papaya', 'lentil', 'chickpea', 'papaya',
#        'chickpea', 'lentil', 'banana', 'mungbean', 'watermelon', 'lentil',
#        'coffee', 'papaya', 'mothbeans', 'blackgram', 'watermelon',
#        'lentil', 'blackgram', 'mungbean', 'maize', 'mothbeans', 'papaya',
#        'blackgram', 'coffee', 'rice', 'grapes', 'pomegranate',
#        'mothbeans', 'banana', 'apple', 'pomegranate', 'kidneybeans',
#        'jute', 'apple', 'mungbean', 'chickpea', 'apple', 'mothbeans',
#        'coconut', 'mungbean', 'muskmelon', 'grapes', 'grapes', 'mungbean',
#        'muskmelon', 'coconut', 'chickpea', 'coffee', 'lentil', 'mango',
#        'pomegranate', 'jute', 'orange', 'maize', 'kidneybeans',
#        'mungbean'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred_2)
# Out:
# 0.9878787878787879
